# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# !pip install pyarrow



# Read the feather file
coffee_ratings = pd.read_feather(r"D:\python Folder\coffee_ratings_full.feather")

# Display the first few rows
coffee_ratings.head()
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#    total_cup_points  species                     owner country_of_origin  \
# 0             90.58  Arabica                 metad plc          Ethiopia
# 1             89.92  Arabica                 metad plc          Ethiopia
# 2             89.75  Arabica  grounds for health admin         Guatemala
# 3             89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4             88.83  Arabica                 metad plc          Ethiopia
#
#                                   farm_name lot_number       mill ico_number  \
# 0                                 metad plc       None  metad plc  2014/2015
# 1                                 metad plc       None  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch       None       None       None
# 3     yidnekachew dabessa coffee plantation       None    wolensu       None
# ...

# %%
pts_vs_flavor_pop = coffee_ratings[["total_cup_points","flavor"]]

# %%
pts_vs_flavor_pop
# Out:
#       total_cup_points  flavor
# 0                90.58    8.83
# 1                89.92    8.67
# 2                89.75    8.50
# 3                89.00    8.58
# 4                88.83    8.50
# ...                ...     ...
# 1333             78.75    7.58
# 1334             78.08    7.67
# 1335             77.17    7.33
# 1336             75.08    6.83
# 1337             73.75    6.67
#
# [1338 rows x 2 columns]

# %%
pts_vs_flavor_samp = pts_vs_flavor_pop.sample(n=10)
pts_vs_flavor_samp
# Out:
#       total_cup_points  flavor
# 377              83.42    7.67
# 1056             80.67    7.17
# 431              83.25    7.58
# 1095             80.25    7.25
# 821              81.92    7.33
# 129              84.67    7.83
# 619              82.67    7.50
# 1017             80.92    7.42
# 1197             79.08    6.75
# 1256             77.25    6.83

# %%
cup_point_samp = coffee_ratings["total_cup_points"].sample(n=10)
print(cup_point_samp)
# Out:
# 348     83.58
# 1261    76.75
# 1025    80.92
# 665     82.50
# 663     82.50
# 1001    81.00
# 624     82.67
# 392     83.42
# 1249    77.67
# 409     83.33
# Name: total_cup_points, dtype: float64

# %%
coffee_ratings.sample(n=5, random_state=19000113)
# Out:
#      total_cup_points  species                           owner  \
# 437             83.25  Arabica  exportadora de cafe condor s.a
# 285             83.83  Arabica                 ipanema coffees
# 784             82.08  Arabica                   cafe politico
# 648             82.58  Arabica  exportadora de cafe condor s.a
# 155             84.58  Arabica  exportadora de cafe condor s.a
#
#     country_of_origin          farm_name lot_number  \
# 437          Colombia               None       None
# 285            Brazil  fazenda rio verde       None
# 784          Colombia               None       None
# 648          Colombia               None       None
# 155          Colombia            various       None
#
#                                       mill     ico_number  \
# 437  trilladora bonanza - armenia quindioa      3-68-0205
# 285                        ipanema coffees  002/4177/0121
# 784                                   None      3-59-1656
# ...

# %%
#Sytematic Sampling:Defining the interval
sample_size=5
pop_size=len(coffee_ratings)
print(pop_size)
# Out:
# 1338

# %%
interval= pop_size//sample_size
interval
# Out:
# 267

# %%
coffee_ratings.iloc[::interval]
# Out:
#       total_cup_points  species                             owner  \
# 0                90.58  Arabica                         metad plc
# 267              83.92  Arabica  federacion nacional de cafeteros
# 534              82.92  Arabica      consejo salvadoreño del café
# 801              82.00  Arabica            lin, che-hao krude 林哲豪
# 1068             80.50  Arabica          cqi taiwan icp cqi台灣合作夥伴
# 1335             77.17  Robusta                       james moore
#
#      country_of_origin                                     farm_name  \
# 0             Ethiopia                                     metad plc
# 267           Colombia                                          None
# 534        El Salvador                                santa josefita
# 801             Taiwan  you siang coffee farmtainan, taiwan 台灣台南優香咖啡
# 1068            Taiwan                                           王秋金
# 1335     United States                               fazenda cazengo
#
# ...

# %%
#plotting
coffee_ratings_with_id = coffee_ratings.reset_index()
coffee_ratings_with_id.plot(x="index", y="aftertaste", kind="scatter")
plt.show()

# %%
# plot seems not safe
# we nned to make it randomized

shuffled= coffee_ratings.sample(frac=1)
shuffled= shuffled.reset_index(drop=True).reset_index()
shuffled.plot(x="index", y="aftertaste", kind="scatter")
plt.show()

# %%
top_counted_countries =["Mexico", "Colombia", "Guatemala", "Brazil", "Taiwan", "United States"]
top_counted_subset = coffee_ratings['country_of_origin'].isin(top_counted_countries)
coffee_ratings_top = coffee_ratings[top_counted_subset]

# %%
coffee_ratings_top
# Out:
#       total_cup_points  species                               owner  \
# 2                89.75  Arabica            grounds for health admin
# 5                88.83  Arabica                           ji-ae ahn
# 11               87.92  Arabica  cqi q coffee sample representative
# 12               87.92  Arabica  cqi q coffee sample representative
# 15               87.58  Arabica  cqi q coffee sample representative
# ...                ...      ...                                 ...
# 1302             70.67  Arabica              volcafe ltda. - brasil
# 1306             68.33  Arabica            juan carlos garcia lopez
# 1309             59.83  Arabica           juan luis alvarado romero
# 1332             79.33  Robusta                       andrew hetzel
# 1335             77.17  Robusta                         james moore
#
#      country_of_origin                                 farm_name  \
# 2            Guatemala  san marcos barrancas "san cristobal cuch
# ...

# %%
#lets get 10% of sampling

coffee_ratings_samp= coffee_ratings_top.sample(frac=0.1, random_state=2021)
coffee_ratings_samp['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Mexico       0.280488
# Colombia     0.243902
# Guatemala    0.195122
# Brazil       0.170732
# Taiwan       0.109756
# Name: proportion, dtype: float64

# %%
#lets get 10% of sampling

coffee_ratings_samp= coffee_ratings_top.sample(frac=1, random_state=2021)
coffee_ratings_samp['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Mexico           0.288862
# Colombia         0.223990
# Guatemala        0.221542
# Brazil           0.161567
# Taiwan           0.091799
# United States    0.012240
# Name: proportion, dtype: float64

# %%
#proportionalstattratified sampling
coffee_ratings_strat=coffee_ratings_top.groupby("country_of_origin").sample(frac=0.1, random_state=2021)
coffee_ratings_strat['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Mexico           0.292683
# Colombia         0.219512
# Guatemala        0.219512
# Brazil           0.158537
# Taiwan           0.097561
# United States    0.012195
# Name: proportion, dtype: float64

# %%
# 15 randomly selected rows from each county
# Select 15 random samples per country
coffee_ratings_eq = coffee_ratings_top.groupby("country_of_origin").sample(n=10, random_state=2021)

# Check proportion of samples per country
coffee_ratings_eq['country_of_origin'].value_counts(normalize=True)
# Out:
# country_of_origin
# Brazil           0.166667
# Colombia         0.166667
# Guatemala        0.166667
# Mexico           0.166667
# Taiwan           0.166667
# United States    0.166667
# Name: proportion, dtype: float64

# %%
# Plot YearsAtCompany from attrition_pop as a histogram
coffee_ratings['country_of_origin'].hist(bins=np.arange(0, 41, 1))
plt.show()

# %%
["species"]
# Out:
# ['species']

# %%
coffee_ratings["country_of_origin"].unique()
# Out:
# array(['Ethiopia', 'Guatemala', 'Brazil', 'Peru', 'United States',
#        'United States (Hawaii)', 'Indonesia', 'China', 'Costa Rica',
#        'Mexico', 'Uganda', 'Honduras', 'Taiwan', 'Nicaragua',
#        'Tanzania, United Republic Of', 'Kenya', 'Thailand', 'Colombia',
#        'Panama', 'Papua New Guinea', 'El Salvador', 'Japan', 'Ecuador',
#        'United States (Puerto Rico)', 'Haiti', 'Burundi', 'Vietnam',
#        'Philippines', 'Rwanda', 'Malawi', 'Laos', 'Zambia', 'Myanmar',
#        'Mauritius', 'Cote d?Ivoire', None, 'India'], dtype=object)

# %%
species= { 'Ethiopia', 'Guatemala', 'Brazil', 'Peru', 'United States',
       'United States (Hawaii)', 'Indonesia', 'China', 'Costa Rica',
       'Mexico', 'Uganda', 'Honduras', 'Taiwan', 'Nicaragua',
       'Tanzania, United Republic Of', 'Kenya', 'Thailand', 'Colombia',
       'Panama', 'Papua New Guinea', 'El Salvador', 'Japan', 'Ecuador',
       'United States (Puerto Rico)', 'Haiti', 'Burundi', 'Vietnam',
       'Philippines', 'Rwanda', 'Malawi', 'Laos', 'Zambia', 'Myanmar',
       'Mauritius', 'Cote d?Ivoire', None, 'India'}
print(species)
# Out:
# {'Philippines', 'Zambia', 'United States', 'Malawi', 'Honduras', 'India', 'United States (Puerto Rico)', 'Vietnam', 'Indonesia', 'Cote d?Ivoire', 'Ethiopia', None, 'Guatemala', 'United States (Hawaii)', 'Taiwan', 'Mauritius', 'Uganda', 'Haiti', 'Rwanda', 'Mexico', 'Brazil', 'El Salvador', 'Colombia', 'Laos', 'China', 'Japan', 'Panama', 'Costa Rica', 'Burundi', 'Thailand', 'Tanzania, United Republic Of', 'Peru', 'Papua New Guinea', 'Nicaragua', 'Kenya', 'Ecuador', 'Myanmar'}

# %%
#varietileri listeleyelim
varieties_pop= list(coffee_ratings['variety'].unique())
varieties_pop
# Out:
# [None,
#  'Other',
#  'Bourbon',
#  'Catimor',
#  'Ethiopian Yirgacheffe',
#  'Caturra',
#  'SL14',
#  'Sumatra',
#  'SL34',
#  'Hawaiian Kona',
#  'Yellow Bourbon',
#  'SL28',
#  'Gesha',
#  'Catuai',
#  'Pacamara',
#  'Typica',
#  'Sumatra Lintong',
#  'Mundo Novo',
#  'Java',
#  'Peaberry',
#  'Pacas',
#  'Mandheling',
#  'Ruiru 11',
#  'Arusha',
#  'Ethiopian Heirlooms',
#  'Moka Peaberry',
#  'Sulawesi',
#  'Blue Mountain',
#  'Marigojipe',
#  'Pache Comun']

# %%
# cluster sampling- sample in sub group

import random
varieties_samp = random.sample(varieties_pop, k=3)
varieties_samp
# Out:
# ['Sumatra Lintong', 'SL14', 'Peaberry']

# %%
#Review

top_counted_countries = ["Mexico", " Columbia", "Guatemala", "Brazil", "Taiwan", "United States (Hawaii)"]
subset_condition = coffee_ratings['country_of_origin'].isin(top_counted_countries)
coffee_ratings_top = coffee_ratings[subset_condition]
coffee_ratings_top.shape
# Out:
# (697, 43)

# %%
coffee_ratings_top
# Out:
#       total_cup_points  species                          owner  \
# 2                89.75  Arabica       grounds for health admin
# 5                88.83  Arabica                      ji-ae ahn
# 13               87.92  Arabica       grounds for health admin
# 22               87.17  Arabica          roberto licona franco
# 25               86.92  Arabica                       nucoffee
# ...                ...      ...                            ...
# 1300             71.00  Arabica  ricardo aaron sampieri marini
# 1301             70.75  Arabica                   kurt kappeli
# 1302             70.67  Arabica         volcafe ltda. - brasil
# 1306             68.33  Arabica       juan carlos garcia lopez
# 1309             59.83  Arabica      juan luis alvarado romero
#
#            country_of_origin                                 farm_name  \
# 2                  Guatemala  san marcos barrancas "san cristobal cuch
# ...

# %%
#Simple random sampling Shudo
coffee_ratings_srs= coffee_ratings_top.sample(frac=1/3, random_state=2021)
coffee_ratings_srs.shape
# Out:
# (232, 43)

# %%
#calculate mean
coffee_ratings_top['total_cup_points'].mean()
# Out:
# np.float64(81.6425538020086)

# %%
len(coffee_ratings.sample(n=300))
# Out:
# 300

# %%
len(coffee_ratings.sample(frac=0.25))
# Out:
# 334

# %%
coffee_ratings.sample(n=3)
# Out:
#      total_cup_points  species                      owner country_of_origin  \
# 732             82.33  Arabica                   nucoffee            Brazil
# 504             83.00  Arabica  juan luis alvarado romero         Guatemala
# 445             83.17  Arabica  juan luis alvarado romero         Guatemala
#
#          farm_name   lot_number                             mill  \
# 732    café citrus         None                             None
# 504  nueva granada         None                      tradicional
# 445   finca medina  11/11711/58  beneficio siembras vision (154)
#
#         ico_number                       company   altitude  ...  color  \
# 732  002/1251/0247                      nucoffee       950m  ...  Green
# 504      11/326/19  agricola nueva granada, s.a.  4500 pies  ...  Green
# 445    11/11711/58         siembras vision, s.a.       1500  ...  Green
#
#     category_two_defects           expiration            certification_body  \
# ...

# %%
print(coffee_ratings['total_cup_points'].mean())
# Out:
# 82.15120328849028

# %%
print(coffee_ratings.sample(n=10)['total_cup_points'].mean())
# Out:
# 81.34899999999999

# %%
print(coffee_ratings.sample(n=100)['total_cup_points'].mean())
# Out:
# 82.12630000000001

# %%
print(coffee_ratings.sample(n=1000)['total_cup_points'].mean())
# Out:
# 82.19015

# %%
print(coffee_ratings.sample(n=1300)['total_cup_points'].mean())
# Out:
# 82.14853076923076

# %%
#Sampling without Replacement

coffee_focus= coffee_ratings[["variety","country_of_origin","flavor"]]
coffee_focus= coffee_focus.reset_index()

# %%
coffee_focus
# Out:
#       index  variety country_of_origin  flavor
# 0         0     None          Ethiopia    8.83
# 1         1    Other          Ethiopia    8.67
# 2         2  Bourbon         Guatemala    8.50
# 3         3     None          Ethiopia    8.58
# 4         4    Other          Ethiopia    8.50
# ...     ...      ...               ...     ...
# 1333   1333     None           Ecuador    7.58
# 1334   1334     None           Ecuador    7.67
# 1335   1335     None     United States    7.33
# 1336   1336     None             India    6.83
# 1337   1337     None           Vietnam    6.67
#
# [1338 rows x 4 columns]

# %%
# Resampling
coffee_resamp= coffee_focus.sample(frac=1, replace=True)

# %%
coffee_resamp
# Out:
#       index  variety             country_of_origin  flavor
# 972     972  Bourbon  Tanzania, United Republic Of    7.17
# 1019   1019    Other  Tanzania, United Republic Of    7.17
# 1017   1017    Other                       Myanmar    7.42
# 843     843  Caturra                    Costa Rica    7.50
# 1110   1110   Typica                        Mexico    7.42
# ...     ...      ...                           ...     ...
# 101     101     SL34                         Kenya    7.83
# 316     316  Caturra                      Honduras    7.50
# 113     113   Catuai                        Brazil    8.00
# 988     988    Other                     Nicaragua    7.33
# 113     113   Catuai                        Brazil    8.00
#
# [1338 rows x 4 columns]

# %%
#Repeated Coffeees
coffee_resamp["index"].value_counts()
# Out:
# index
# 619    5
# 866    5
# 749    5
# 410    5
# 240    5
#       ..
# 483    1
# 785    1
# 966    1
# 455    1
# 360    1
# Name: count, Length: 843, dtype: int64

# %%
# unique numbers of coffes

num_unique_coffees = len(coffee_resamp.drop_duplicates(subset="index"))
num_unique_coffees
# Out:
# 843
