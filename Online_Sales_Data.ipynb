# %%
import pandas as pd

# Path to the Excel file
file_path = r"D:\Python Folder\Yearly Sales analysis.xlsm"

# Read the Excel file
df = pd.read_excel(file_path)

# Display the first few rows of the data
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
print(df.keys())
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df["unit_price"] = df["Sales"]/df["Quantity"]

# %%
print(df.keys())
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'unit_price'],
#       dtype='object')

# %%
# Index df by country & city
df_ind = df.set_index(['City', 'State'])

# List of tuples: Brazil, Rio De Janeiro & Pakistan, Lahore
hangi_sahir_eyalet = [('Miami', 'Florida')]

# Subset for rows to keep
df_ind.loc[hangi_sahir_eyalet]
# Out:
#                Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# City  State
# Miami Florida     403  CA-2014-113166 2014-12-24 2014-12-26     First Class
#       Florida     634  CA-2017-144694 2017-09-24 2017-09-26    Second Class
#       Florida     635  CA-2017-144694 2017-09-24 2017-09-26    Second Class
#       Florida    1047  CA-2016-169103 2016-03-08 2016-03-13  Standard Class
#       Florida    1048  CA-2016-169103 2016-03-08 2016-03-13  Standard Class
#       Florida    1531  CA-2015-103793 2015-03-26 2015-03-31  Standard Class
#       Florida    1898  CA-2014-169775 2014-08-29 2014-09-02    Second Class
#       Florida    1899  CA-2014-169775 2014-08-29 2014-09-02    Second Class
#       Florida    1900  CA-2014-169775 2014-08-29 2014-09-02    Second Class
#       Florida    2271  CA-2017-164917 2017-12-02 2017-12-07  Standard Class
#       Florida    2500  US-2017-133781 2017-06-22 2017-06-23     First Class
# ...

# %%
# Index df TEK SEHIR UZERINDEN ALABILIRIZ
df_ind = df.set_index(['City'])

# List of tuples: SADECE MIAMI YE BAKALIM
hangi_sahir_eyalet = [('Miami')]

# Subset for rows to keep
df_ind.loc[hangi_sahir_eyalet]
# Out:
#        Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# City
# Miami     403  CA-2014-113166 2014-12-24 2014-12-26     First Class
# Miami     634  CA-2017-144694 2017-09-24 2017-09-26    Second Class
# Miami     635  CA-2017-144694 2017-09-24 2017-09-26    Second Class
# Miami    1047  CA-2016-169103 2016-03-08 2016-03-13  Standard Class
# Miami    1048  CA-2016-169103 2016-03-08 2016-03-13  Standard Class
# Miami    1531  CA-2015-103793 2015-03-26 2015-03-31  Standard Class
# Miami    1898  CA-2014-169775 2014-08-29 2014-09-02    Second Class
# Miami    1899  CA-2014-169775 2014-08-29 2014-09-02    Second Class
# Miami    1900  CA-2014-169775 2014-08-29 2014-09-02    Second Class
# Miami    2271  CA-2017-164917 2017-12-02 2017-12-07  Standard Class
# Miami    2500  US-2017-133781 2017-06-22 2017-06-23     First Class
# Miami    2801  CA-2016-153318 2016-10-25 2016-10-28     First Class
# Miami    3265  CA-2016-122518 2016-03-04 2016-03-08    Second Class
# ...

# %%
# ILK OLARAK ANA INDEX TE BIR DEGISKEN TANMLARIZ
# SONRA BUNA AIT ALT DEGISKENLERDEN BIRINE ARIYORSAK , 
# ORNEGIN "Category" ler icinden sadece "Technology" urunlerini yazdirmak iicin  
df_ind = df.set_index(['Category'])
df_ind.loc[[('Technology')]]
# Out:
#             Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# Category
# Technology       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# Technology      12  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# Technology      20  CA-2014-143336 2014-08-27 2014-09-01    Second Class
# Technology      27  CA-2016-121755 2016-01-16 2016-01-20    Second Class
# Technology      36  CA-2016-117590 2016-12-08 2016-12-10     First Class
# ...            ...             ...        ...        ...             ...
# Technology    9984  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# Technology    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# Technology    9988  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# Technology    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# Technology    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#            Customer ID       Customer Name    Segment        Country  \
# ...

# %%
df.loc["Aberdeen":"Miami"]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, unit_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
print(df.iloc[8:13, 5:9])
# Out:
#    Customer ID    Customer Name   Segment        Country
# 8     BH-11710  Brosina Hoffman  Consumer  United States
# 9     BH-11710  Brosina Hoffman  Consumer  United States
# 10    BH-11710  Brosina Hoffman  Consumer  United States
# 11    BH-11710  Brosina Hoffman  Consumer  United States
# 12    AA-10480     Andrew Allen  Consumer  United States

# %%
df.loc["State":"City"]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, unit_price]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#       index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0         0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1         1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2         2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3         3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4         4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...     ...     ...             ...        ...        ...             ...
# 9989   9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990   9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991   9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992   9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993   9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country  ... Region  \
# ...

# %%
# Get 23rd row, 2nd column (index 22, 1)
df.iloc[22, 1]
# Out:
# np.int64(23)

# %%
# Use slicing to get the first 5 rows
df.iloc[:5, :]
# Out:
#    index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0      0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1      1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2      2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3      3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4      4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
#
#   Customer ID    Customer Name    Segment        Country  ... Region  \
# 0    CG-12520      Claire Gute   Consumer  United States  ...  South
# 1    CG-12520      Claire Gute   Consumer  United States  ...  South
# 2    DV-13045  Darrin Van Huff  Corporate  United States  ...   West
# 3    SO-20335   Sean O'Donnell   Consumer  United States  ...  South
# 4    SO-20335   Sean O'Donnell   Consumer  United States  ...  South
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
# Use slicing to get columns 3 to 4
df.iloc[:, 2:4]
# Out:
#             Order ID Order Date
# 0     CA-2016-152156 2016-11-08
# 1     CA-2016-152156 2016-11-08
# 2     CA-2016-138688 2016-06-12
# 3     US-2015-108966 2015-10-11
# 4     US-2015-108966 2015-10-11
# ...              ...        ...
# 9989  CA-2014-110422 2014-01-21
# 9990  CA-2017-121258 2017-02-26
# 9991  CA-2017-121258 2017-02-26
# 9992  CA-2017-121258 2017-02-26
# 9993  CA-2017-119914 2017-05-04
#
# [9994 rows x 2 columns]

# %%
# Use slicing in both directions at once

df.iloc[:5, 2:4]
# Out:
#          Order ID Order Date
# 0  CA-2016-152156 2016-11-08
# 1  CA-2016-152156 2016-11-08
# 2  CA-2016-138688 2016-06-12
# 3  US-2015-108966 2015-10-11
# 4  US-2015-108966 2015-10-11

# %%
print(df.keys())
# Out:
# Index(['index', 'Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit',
#        'unit_price'],
#       dtype='object')

# %%
df.pivot_table(values='unit_price', index='Sub-Category', columns='Category', fill_value=0, margins=True).round(0)
# Out:
# Category      Furniture  Office Supplies  Technology    All
# Sub-Category
# Accessories         0.0              0.0        55.0   55.0
# Appliances          0.0             61.0         0.0   61.0
# Art                 0.0              9.0         0.0    9.0
# Binders             0.0             37.0         0.0   37.0
# Bookcases         131.0              0.0         0.0  131.0
# Chairs            139.0              0.0         0.0  139.0
# Copiers             0.0              0.0       601.0  601.0
# Envelopes           0.0             19.0         0.0   19.0
# Fasteners           0.0              3.0         0.0    3.0
# Furnishings        26.0              0.0         0.0   26.0
# Labels              0.0              8.0         0.0    8.0
# Machines            0.0              0.0       423.0  423.0
# Paper               0.0             16.0         0.0   16.0
# Phones              0.0              0.0       101.0  101.0
# ...

# %%
df.pivot_table(values="Sales", index ="State", columns ="Category", fill_value =0, margins=True).round(2)
# Out:
# Category              Furniture  Office Supplies  Technology      All
# State
# Alabama                  575.68           116.92      640.65   319.85
# Arizona                  276.03            78.79      244.81   157.51
# Arkansas                 354.17           126.81      261.68   194.64
# California               351.50           118.82      443.65   228.73
# Colorado                 259.67            82.28      313.32   176.42
# Connecticut              398.08            93.42      253.73   163.22
# Delaware                 264.41           140.16      728.11   285.95
# District of Columbia     448.86            23.09     1379.92   286.50
# Florida                  270.44            85.23      680.70   233.61
# Georgia                  260.05           232.31      379.96   266.83
# Idaho                    432.58            86.32      209.37   208.69
# Illinois                 229.87            69.85      380.76   162.94
# ...

# %%
filtered_sales = df[df["State"].isin(["Category", "Sub-Category"])]
print(filtered_sales.groupby(['Category' ,'Sub-Category']) ['Profit'].min())
# Out:
# Series([], Name: Profit, dtype: float64)

# %%
# CATEGORY VE SUB-CATEGORY BAZINDA EN COK ZARAR EDEN SATISLAR

print(df.groupby(['Category', 'Sub-Category'])['Profit'].min())
# Out:
# Category         Sub-Category
# Furniture        Bookcases      -1665.0522
#                  Chairs          -630.8820
#                  Furnishings     -427.4500
#                  Tables         -1862.3124
# Office Supplies  Appliances     -1181.2824
#                  Art                0.1533
#                  Binders        -3701.8928
#                  Envelopes          0.5508
#                  Fasteners        -11.8256
#                  Labels             0.6786
#                  Paper              1.0700
#                  Storage         -337.8060
#                  Supplies       -1049.3406
# Technology       Accessories      -75.5958
#                  Copiers           59.9980
#                  Machines       -6599.9780
#                  Phones          -386.3916
# Name: Profit, dtype: float64

# %%
df["Sub-Category"].drop_duplicates()
# Out:
# 0        Bookcases
# 1           Chairs
# 2           Labels
# 3           Tables
# 4          Storage
# 5      Furnishings
# 6              Art
# 7           Phones
# 8          Binders
# 9       Appliances
# 12           Paper
# 26     Accessories
# 30       Envelopes
# 53       Fasteners
# 138       Supplies
# 165       Machines
# 335        Copiers
# Name: Sub-Category, dtype: object

# %%
#category ve sub-Category bazinda profit listesi , kucuktan buyuge
print(df.groupby(['Category', 'Sub-Category'])['Profit'].sum().round().sort_values())
# Out:
# Category         Sub-Category
# Furniture        Tables         -17725.0
#                  Bookcases       -3473.0
# Office Supplies  Supplies        -1189.0
#                  Fasteners         950.0
# Technology       Machines         3385.0
# Office Supplies  Labels           5546.0
#                  Art              6528.0
#                  Envelopes        6964.0
# Furniture        Furnishings     13059.0
# Office Supplies  Appliances      18138.0
#                  Storage         21279.0
# Furniture        Chairs          26590.0
# Office Supplies  Binders         30222.0
#                  Paper           34054.0
# Technology       Accessories     41937.0
#                  Phones          44516.0
#                  Copiers         55618.0
# Name: Profit, dtype: float64

# %%
print(df.groupby(['Category', 'Sub-Category'])['Profit'].sum().round(2).sort_values().apply(lambda x: "{:,.2f}".format(x)))
# Out:
# Category         Sub-Category
# Furniture        Tables          -17,725.48
#                  Bookcases        -3,472.56
# Office Supplies  Supplies         -1,189.10
#                  Fasteners           949.52
# Technology       Machines          3,384.76
# Office Supplies  Labels            5,546.25
#                  Art               6,527.79
#                  Envelopes         6,964.18
# Furniture        Furnishings      13,059.14
# Office Supplies  Appliances       18,138.01
#                  Storage          21,278.83
# Furniture        Chairs           26,590.17
# Office Supplies  Binders          30,221.76
#                  Paper            34,053.57
# Technology       Accessories      41,936.64
#                  Phones           44,515.73
#                  Copiers          55,617.82
# Name: Profit, dtype: object

# %%
import matplotlib.pyplot as plt

# Veri hazırlığı
profit_data = df.groupby(['Category', 'Sub-Category'])['Profit'].sum().round(2).sort_values()

# Çubuk grafiği oluştur
fig, ax = plt.subplots(figsize=(12, 6))

# Negatif değerler kırmızı, pozitif değerler yeşil renk olacak şekilde ayarla
colors = profit_data.apply(lambda x: 'green' if x > 0 else 'red')

# Çubuk grafiği çiz
profit_data.plot(kind='bar', ax=ax, color=colors)

# Başlık ve etiketler
ax.set_title('Total Profit by Category and Sub-Category', fontsize=14)
ax.set_xlabel('Category and Sub-Category', fontsize=12)
ax.set_ylabel('Profit (in USD)', fontsize=12)

# Y ekseninde 1000 ayracı ve yuvarlama
plt.tick_params(axis='y', labelsize=10)
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(x)))

# Grafik gösterimi
plt.tight_layout()
plt.show()

# %%
print(df[df["Sub-Category"] == "Tables"])
# Out:
#       index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3         3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 10       10      11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 24       24      25  CA-2015-106320 2015-09-25 2015-09-30  Standard Class
# 117     117     118  CA-2015-110457 2015-03-02 2015-03-06  Standard Class
# 125     125     126  US-2014-134614 2014-09-20 2014-09-25  Standard Class
# ...     ...     ...             ...        ...        ...             ...
# 9857   9857    9858  CA-2015-164301 2015-03-26 2015-03-30  Standard Class
# 9899   9899    9900  US-2014-117380 2014-03-28 2014-04-03  Standard Class
# 9937   9937    9938  CA-2016-164889 2016-06-03 2016-06-06    Second Class
# 9955   9955    9956  CA-2015-141593 2015-12-14 2015-12-16    Second Class
# 9980   9980    9981  US-2015-151435 2015-09-06 2015-09-09    Second Class
#
#      Customer ID    Customer Name      Segment        Country  ...   Region  \
# ...

# %%
df[df["Sub-Category"] == "Tables"][["Sales", "Quantity", "Profit"]]
# Out:
#           Sales  Quantity    Profit
# 3      957.5775         5 -383.0310
# 10    1706.1840         9   85.3092
# 24    1044.6300         3  240.2649
# 117    787.5300         3  165.3813
# 125    617.7000         6 -407.6820
# ...         ...       ...       ...
# 9857  3393.6800         8  610.8624
# 9899   330.5880         1 -143.2548
# 9937    71.0880         2   -1.7772
# 9955   273.5680         2   10.2588
# 9980    85.9800         1   22.3548
#
# [319 rows x 3 columns]

# %%
#Tables satislarini toplam Sales, Quantity ve Profir degerleri soyle yazilir

tables_sales = df[df["Sub-Category"] == "Tables"]

# Bir arada toplamları yazdırmak
totals = tables_sales[["Sales", "Quantity", "Profit"]].sum()
print(totals)
# Out:
# Sales       206965.5320
# Quantity      1241.0000
# Profit      -17725.4811
# dtype: float64

# %%
df.describe()
# Out:
#              index       Row ID                     Order Date  \
# count  9994.000000  9994.000000                           9994
# mean   4996.500000  4997.500000  2016-04-30 00:07:12.259355648
# min       0.000000     1.000000            2014-01-03 00:00:00
# 25%    2498.250000  2499.250000            2015-05-23 00:00:00
# 50%    4996.500000  4997.500000            2016-06-26 00:00:00
# 75%    7494.750000  7495.750000            2017-05-14 00:00:00
# max    9993.000000  9994.000000            2017-12-30 00:00:00
# std    2885.163629  2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# ...

# %%
plt.scatter( df["Sales"],df["Category"] )

# %%
df.sort_values(["Sales"], ascending=False)
# Out:
#       index  Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697   2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
# 6826   6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153   8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 2623   2623    2624  CA-2017-127180 2017-10-22 2017-10-24     First Class
# 4190   4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# ...     ...     ...             ...        ...        ...             ...
# 2106   2106    2107  US-2014-152723 2014-09-26 2014-09-26        Same Day
# 4711   4711    4712  CA-2014-112403 2014-03-31 2014-03-31        Same Day
# 8658   8658    8659  CA-2016-168361 2016-06-21 2016-06-25  Standard Class
# 9292   9292    9293  CA-2017-124114 2017-03-02 2017-03-02        Same Day
# 4101   4101    4102  US-2017-102288 2017-06-19 2017-06-23  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  ...   Region  \
# ...

# %%
df.pivot_table( values="Sales", index="Profit", columns="Category", fill_value=0)
# Out:
# Category    Furniture  Office Supplies  Technology
# Profit
# -6599.9780        0.0            0.000    4499.985
# -3839.9904        0.0            0.000    7999.980
# -3701.8928        0.0         2177.584       0.000
# -3399.9800        0.0            0.000    2549.985
# -2929.4845        0.0         1889.990       0.000
# ...               ...              ...         ...
#  4630.4755        0.0         9449.950       0.000
#  4946.3700        0.0         9892.740       0.000
#  5039.9856        0.0            0.000   10499.970
#  6719.9808        0.0            0.000   13999.960
#  8399.9760        0.0            0.000   17499.950
#
# [7545 rows x 3 columns]

# %%
df["Category"].value_counts(sort=True).head()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df["Sub-Category"].value_counts(sort=True).head()
# Out:
# Sub-Category
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Name: count, dtype: int64

# %%
df[["Category","Sub-Category"]].value_counts,"normalize"==True
# Out:
# (<bound method DataFrame.value_counts of              Category Sub-Category
#  0           Furniture    Bookcases
#  1           Furniture       Chairs
#  2     Office Supplies       Labels
#  3           Furniture       Tables
#  4     Office Supplies      Storage
#  ...               ...          ...
#  9989        Furniture  Furnishings
#  9990        Furniture  Furnishings
#  9991       Technology       Phones
#  9992  Office Supplies        Paper
#  9993  Office Supplies   Appliances
#
#  [9994 rows x 2 columns]>,
#  False)

# %%
print(df["Sub-Category"].value_counts(normalize= True))
# Out:
# Sub-Category
# Binders        0.152391
# Paper          0.137082
# Furnishings    0.095757
# Phones         0.088953
# Storage        0.084651
# Art            0.079648
# Accessories    0.077547
# Chairs         0.061737
# Appliances     0.046628
# Labels         0.036422
# Tables         0.031919
# Envelopes      0.025415
# Bookcases      0.022814
# Fasteners      0.021713
# Supplies       0.019011
# Machines       0.011507
# Copiers        0.006804
# Name: proportion, dtype: float64

# %%
filtered_sales = df[df["Category"].isin(["Storage", "Phones"])]
print(filtered_sales.drop_duplicates(subset = ['Category','Sub-Category'] ))

# %%
df['Profit'].mean()
# Out:
# np.float64(28.656896307784663)

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.isnull().sum()
# Out:
# index            0
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# unit_price       0
# dtype: int64
